# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("D:\\dataset\\netflix_titles.csv")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df2 = df.copy()
df2.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
# dropping null value
df2.dropna(inplace = True)

# %%
df2.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df2.nunique()
# Out:
# show_id         5332
# type               2
# title           5332
# director        3945
# cast            5200
# country          604
# date_added      1453
# release_year      72
# rating            14
# duration         198
# listed_in        335
# description     5321
# dtype: int64

# %%
# creating a new varible movies for just movie type show
movies = df2[df2['type'] == 'Movie']

# %%
# Calculating average movie duration 

movies['duration_minutes'] = movies['duration'].str.replace(' min', '', regex=False)
movies['duration_minutes'] = pd.to_numeric(movies['duration_minutes'], errors='coerce')
movies = movies.dropna(subset=['duration_minutes'])

average_duration = movies['duration_minutes'].mean()
print(f"Average movie duration: {average_duration:.2f} minutes")
# Out:
# Average movie duration: 102.70 minutes
# C:\Users\Babita\AppData\Local\Temp\ipykernel_16508\456876107.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['duration_minutes'] = movies['duration'].str.replace(' min', '', regex=False)
# C:\Users\Babita\AppData\Local\Temp\ipykernel_16508\456876107.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['duration_minutes'] = pd.to_numeric(movies['duration_minutes'], errors='coerce')

# %%
movies['duration_minutes'] = movies['duration'].str.replace(' min', '').astype(float)
sns.boxplot(data= movies , x='duration_minutes')
plt.title('Distribution of Movie Durations')
# Out:
# Text(0.5, 1.0, 'Distribution of Movie Durations')

# %%
tv_shows = df2[df2['type'] == 'TV Show']

tv_shows['seasons'] = tv_shows['duration'].str.replace(' Season', '', regex=False)
tv_shows['seasons'] = tv_shows['seasons'].str.replace('s', '', regex=False)
# Out:
# C:\Users\Babita\AppData\Local\Temp\ipykernel_16508\2130794326.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_shows['seasons'] = tv_shows['duration'].str.replace(' Season', '', regex=False)
# C:\Users\Babita\AppData\Local\Temp\ipykernel_16508\2130794326.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_shows['seasons'] = tv_shows['seasons'].str.replace('s', '', regex=False)

# %%
plt.figure(figsize=(8, 4))
sns.countplot(data=tv_shows, x='seasons', order=tv_shows['seasons'].value_counts().index[:10])
plt.title('TV Shows by Number of Seasons')
plt.xlabel('Seasons')
plt.ylabel('Count')
plt.show()

# %%
tv_shows['season_type'] = tv_shows['seasons'].apply(lambda x: '1 Season' if x == '1' else 'More than 1')
season_counts = tv_shows['season_type'].value_counts()

plt.figure(figsize=(6, 6))
season_counts.plot.pie(autopct='%1.1f%%', colors=['#66b3ff', '#ff9999'], startangle=90)
plt.title('TV Shows: 1 Season vs More than 1')
plt.ylabel('')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Babita\AppData\Local\Temp\ipykernel_16508\2322088466.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_shows['season_type'] = tv_shows['seasons'].apply(lambda x: '1 Season' if x == '1' else 'More than 1')

# %%
plt.hist(df2["release_year"], color='coral', edgecolor='gold')
plt.xlabel("release_year")
plt.ylabel("freaquency")
plt.title(" Distribution of Content by Release Year")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df2['type'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['#66b3ff','#ff9999'])
plt.ylabel('')
plt.title("Count of Movie v/s TV Show")
# Out:
# Text(0.5, 1.0, 'Count of Movie v/s TV Show')

# %%
df2['country'].value_counts().head(10).plot(kind='barh', color='teal')
plt.xlabel("Count")
plt.ylabel("Country")
plt.title("Top 10 Country by Content Count")
# Out:
# Text(0.5, 1.0, 'Top 10 Country by Content Count')

# %%
df2.groupby('release_year').size().plot(kind='line')
plt.xlabel("Release Year")
plt.ylabel("Number of Shows")
plt.title("Rise of Number of Shows")
# Out:
# Text(0.5, 1.0, 'Rise of Number of Shows')

# %%
df2['genre_split'] = df['listed_in'].str.split(',')
df2_exploded = df2.explode('genre_split')
df2_exploded['genre_split'] = df2_exploded['genre_split'].str.strip()
genre_counts = df2_exploded['genre_split'].value_counts()
print(genre_counts.head(10))
# Out:
# genre_split
# International Movies        2369
# Dramas                      2293
# Comedies                    1553
# Action & Adventure           806
# Independent Movies           740
# Romantic Movies              579
# Thrillers                    547
# Children & Family Movies     503
# Documentaries                391
# Horror Movies                336
# Name: count, dtype: int64

# %%
genre_counts.head(10).plot(kind='barh', color='coral')
plt.title("Top 10 Genres on Netflix")
plt.xlabel("Genre")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
top_directors = df2['director'].value_counts().head(10) 

# Plot
plt.figure(figsize=(10, 5))
top_directors.plot(kind='barh', color='skyblue')
plt.xlabel('Number of Titles')
plt.title('Top 10 Directors on Netflix')
plt.gca().invert_yaxis()  # To show highest at the top
plt.tight_layout()
plt.show()
